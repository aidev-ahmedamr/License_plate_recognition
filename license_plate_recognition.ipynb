# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b01a88f6-ff49-43a2-a762-317ec0f8fb16" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b01a88f6-ff49-43a2-a762-317ec0f8fb16">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !unzip -q plate_system_fixed.zip
# %cd plate_system
# !ls -la
# Out:
# /content/plate_system
# total 11916
# drwxr-xr-x 7 root root    4096 Aug 24 14:21 .
# drwxr-xr-x 1 root root    4096 Aug 24 14:42 ..
# -rw-r--r-- 1 root root    4202 Aug 18 01:51 api.py
# drwxr-xr-x 5 root root    4096 Aug 24 14:20 dataset
# -rw-r--r-- 1 root root     546 Aug 18 01:51 Dockerfile
# -rw-r--r-- 1 root root    4802 Aug 18 01:51 evaluate.py
# drwxr-xr-x 3 root root    4096 Aug 18 07:20 .github
# -rw-r--r-- 1 root root     413 Aug 18 07:21 .gitignore
# -rw-r--r-- 1 root root    1066 Aug 18 07:20 LICENSE
# -rw-r--r-- 1 root root   14187 Aug 16 07:29 pipeline.py
# -rw-r--r-- 1 root root   10681 Aug 18 07:59 plate_reader.py
# -rw-r--r-- 1 root root    6316 Aug 18 07:21 README.md
# -rw-r--r-- 1 root root     113 Aug 18 01:51 requirements.txt
# drwxr-xr-x 3 root root    4096 Aug 24 14:21 runs
# drwxr-xr-x 2 root root    4096 Aug 18 07:21 tests
# drwxr-xr-x 3 root root    4096 Aug 18 07:21 test_set
# -rw-r--r-- 1 root root    2735 Aug 16 07:30 train_detector.py
# ...

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="waktspBnxlCrLleS76b1")
project = rf.workspace("roboflow-universe-projects").project("license-plate-recognition-rxg4e")
version = project.version(4)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to License-Plate-Recognition-4 in yolov8:: 100%|██████████| 48488/48488 [00:09<00:00, 5009.84it/s]

# %%
# !ls
# Out:
# api.py	     LICENSE			  README.md	    test_set
# dataset      License-Plate-Recognition-4  requirements.txt  train_detector.py
# Dockerfile   pipeline.py		  runs		    yolo26n.pt
# evaluate.py  plate_reader.py		  tests		    yolov8n.pt

# %%
# !mv "License-Plate-Recognition-4" dataset
# !cat dataset/data.yaml
# Out:
# names:
# - License_Plate
# nc: 1
# roboflow:
#   license: CC BY 4.0
#   project: license-plate-recognition-rxg4e
#   url: https://universe.roboflow.com/roboflow-universe-projects/license-plate-recognition-rxg4e/dataset/4
#   version: 4
#   workspace: roboflow-universe-projects
# test: ../test/images
# train: ../train/images
# val: ../valid/images

# %%
# !pip install ultralytics -q
# !python train_detector.py --data dataset/data.yaml --epochs 10 --device 0
# Out:
# Fine-tuning yolov8n.pt on dataset/data.yaml for 10 epochs...
# Ultralytics 8.4.127 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !find runs -name "best.pt"
# Out:
# runs/detect/runs/detect/train/weights/best.pt
# runs/detect/runs/detect/train-3/weights/best.pt
# runs/detect/runs/detect/train-4/weights/best.pt

# %%
from google.colab import files
files.download('runs/detect/runs/detect/train-4/weights/best.pt')
